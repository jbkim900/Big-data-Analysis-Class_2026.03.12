# %% [markdown]
# # 8장. 텍스트 빈도 분석 (1)영어단어분석

# %%
# !pip install matplotlib

# %%
# !pip install wordcloud

# %% [markdown]
# ### - 자연어처리패키지 nltk download

# %%
import nltk

# %%
nltk.download()

# %% [markdown]
# #### -----------------------------------------------------------------

# %% [markdown]
# # 4. 데이터 준비

# %%
import pandas as pd
import glob
import re
from functools import reduce

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import STOPWORDS, WordCloud

# %% [markdown]
# ## 데이터 조합 – 파일 병합하기

# %%
all_files = glob.glob('/content/myCabinetExcelData*.xlsx')
all_files #출력하여 내용 확인
# Out:
# ['/content/myCabinetExcelData (1).xlsx',
#  '/content/myCabinetExcelData (3).xlsx',
#  '/content/myCabinetExcelData (8).xlsx',
#  '/content/myCabinetExcelData (7).xlsx',
#  '/content/myCabinetExcelData (6).xlsx',
#  '/content/myCabinetExcelData (2).xlsx',
#  '/content/myCabinetExcelData (5).xlsx',
#  '/content/myCabinetExcelData.xlsx',
#  '/content/myCabinetExcelData (9).xlsx',
#  '/content/myCabinetExcelData (4).xlsx']

# %%
#"ImportError: Missing optional dependency 'xlrd'." 에러 발생 시, xlrd 패키지 설치하기
# !pip install xlrd
# Out:
# Requirement already satisfied: xlrd in /usr/local/lib/python3.12/dist-packages (2.0.2)

# %%
all_files_data = [] #저장할 리스트
for file in all_files:
    data_frame = pd.read_excel(file)
    all_files_data.append(data_frame)

all_files_data[0] #작업 내용 확인
# Out:
#     Unnamed: 0   번호                                                 제목  \
# 0          NaN    1  Call for Special Issue Papers: Soft Computing ...
# 1          NaN    2  Big Data, Efficient Markets, and the End of Da...
# 2          NaN    3   Big Data and Predictive Analytics in Health Care
# 3          NaN    4  Call for Special Issue Papers: Internet of Med...
# 4          NaN    5                         Big Data Literature Search
# ..         ...  ...                                                ...
# 95         NaN   96  A survey on big data processing infrastructure...
# 96         NaN   97  Toward Efficient and Flexible Metadata Indexin...
# 97         NaN   98  Distributed Feature Selection for Efficient Ec...
# 98         NaN   99  A platform for big data analytics on distribut...
# 99         NaN  100  Towards quality-of-service driven consistency ...
#
#                                                    저자               출판사   출판일
# 0      Chilamkurti, Naveen; Paul, Anand; Kumar, Akshi  Mary Ann Leibert  2020
# 1                   Urbaczewski, Andrew; Elmore, Ryan  Mary Ann Leibert  2018
# 2                                             unknown  Mary Ann Leibert  2014
# 3   Din, Sadia; Aslan, Nauman; Cheung, Simon K.S.;...  Mary Ann Leibert  2020
# 4                                             unknown  Mary Ann Leibert  2014
# ..                                                ...               ...   ...
# 95  Nunna, Krishna Chaitanya; Mehdipour, Farhad; T...      Inderscience  2015
# 96  Zhao, D.; Qiao, K.; Zhou, Z.; Li, T.; Lu, Z.; ...           unknown  2017
# 97     Zhao, L.; Chen, Z.; Hu, Y.; Min, G.; Jiang, Z.           unknown  2018
# 98                      Aye, Kyar Nyo; Thein, Thandar      Inderscience  2015
# 99  García-Recuero, Álvaro; Esteves, Sérgio; Veiga...      Inderscience  2014
#
# [100 rows x 6 columns]

# %%
all_files_data_concat = pd.concat( all_files_data, axis = 0, ignore_index = True)
all_files_data_concat #출력하여 내용 확인
# Out:
#      Unnamed: 0   번호                                                 제목  \
# 0           NaN    1  Call for Special Issue Papers: Soft Computing ...
# 1           NaN    2  Big Data, Efficient Markets, and the End of Da...
# 2           NaN    3   Big Data and Predictive Analytics in Health Care
# 3           NaN    4  Call for Special Issue Papers: Internet of Med...
# 4           NaN    5                         Big Data Literature Search
# ..          ...  ...                                                ...
# 995         NaN   96  Integrative Biology and Big-Data-Centrism: Map...
# 996         NaN   97  Industrial Symbiosis: Exploring Big-data Appro...
# 997         NaN   98  Israeli firm MedAware offers big-data software...
# 998         NaN   99  A sustainable Ethereum merge-based Big-Data ga...
# 999         NaN  100               Daten und Diabetes: Big-Data-Medizin
#
#                                                     저자  \
# 0       Chilamkurti, Naveen; Paul, Anand; Kumar, Akshi
# 1                    Urbaczewski, Andrew; Elmore, Ryan
# 2                                              unknown
# 3    Din, Sadia; Aslan, Nauman; Cheung, Simon K.S.;...
# 4                                              unknown
# ..                                                 ...
# 995        Überall, Martina; Werner-Felmayer, Gabriele
# 996  Song, Bin; Yeo, Zhiquan; Kohls, Paul; Herrmann...
# 997                                     Rice,  Sabriya
# 998                                       Sharma, Ravi
# 999                                        Ickrath, M.
#
#                                    출판사   출판일
# 0                     Mary Ann Leibert  2020
# 1                     Mary Ann Leibert  2018
# 2                     Mary Ann Leibert  2014
# 3                     Mary Ann Leibert  2020
# 4                     Mary Ann Leibert  2014
# ..                                 ...   ...
# 995                   Mary Ann Leibert  2019
# 996   Elsevier Science B.V., Amsterdam  2017
# 997          CRAIN COMMUNICATIONS INC.  2015
# 998   Elsevier Science B.V., Amsterdam  2023
# 999  Springer Science + Business Media  2016
#
# [1000 rows x 6 columns]

# %%
all_files_data_concat.to_csv( 'riss_bigdata.csv', encoding = 'utf-8', index = False)

# %% [markdown]
# ## 데이터 전처리

# %%
all_title = all_files_data_concat['제목']
all_title #출력하여 내용 확인
# Out:
# 0      Call for Special Issue Papers: Soft Computing ...
# 1      Big Data, Efficient Markets, and the End of Da...
# 2       Big Data and Predictive Analytics in Health Care
# 3      Call for Special Issue Papers: Internet of Med...
# 4                             Big Data Literature Search
#                              ...
# 995    Integrative Biology and Big-Data-Centrism: Map...
# 996    Industrial Symbiosis: Exploring Big-data Appro...
# 997    Israeli firm MedAware offers big-data software...
# 998    A sustainable Ethereum merge-based Big-Data ga...
# 999                 Daten und Diabetes: Big-Data-Medizin
# Name: 제목, Length: 1000, dtype: object

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
stopWords = set(stopwords.words("english"))
lemma = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
words = []
for title in all_title:
    EnWords = re.sub(r"[^a-zA-Z]+", " ", str(title))
    EnWordsToken = word_tokenize(EnWords.lower())
    EnWordsTokenStop = [ w for w in EnWordsToken if w not in stopWords]
    EnWordsTokenStopLemma = [ lemma.lemmatize(w) for w in EnWordsTokenStop]
    words.append(EnWordsTokenStopLemma)

# %%
print(words) #출력하여 내용 확인
# Out:
# [['call', 'special', 'issue', 'paper', 'soft', 'computing', 'model', 'big', 'data', 'internet', 'thing'], ['big', 'data', 'efficient', 'market', 'end', 'daily', 'fantasy', 'sport', 'know'], ['big', 'data', 'predictive', 'analytics', 'health', 'care'], ['call', 'special', 'issue', 'paper', 'internet', 'medical', 'thing', 'big', 'data', 'pervasive', 'medical', 'care'], ['big', 'data', 'literature', 'search'], ['big', 'data', 'ensemble', 'clinical', 'prediction', 'healthcare', 'data', 'using', 'deep', 'learning', 'model'], ['call', 'special', 'issue', 'paper', 'cloud', 'computing', 'big', 'data', 'cognitive', 'iot'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'industrial', 'intelligence'], ['u', 'army', 'person', 'event', 'data', 'environment', 'military', 'civilian', 'big', 'data', 'enterprise'], ['exploiting', 'reused', 'based', 'sharing', 'work', 'opportunity', 'big', 'data', 'multiquery', 'optimization', 'flink'], ['big', 'data', 'machine', 'analyze', 'stock', 'market', 'sentiment'], ['overcoming', 'resistance', 'big', 'data', 'operational', 'change', 'interactive', 'data', 'visualization'], ['call', 'special', 'issue', 'paper', 'multimedia', 'big', 'data', 'analytics', 'engineering', 'education'], ['big', 'data', 'lost', 'cloud'], ['call', 'special', 'issue', 'paper', 'cloud', 'computing', 'big', 'data', 'cognitive', 'iot'], ['big', 'data', 'social', 'good'], ['big', 'data', 'rise', 'machine', 'financial', 'market'], ['big', 'data', 'support', 'sustainable', 'development', 'goal', 'continued', 'celebration', 'establishment', 'international', 'research', 'center', 'big', 'data', 'sustainable', 'development', 'goal', 'cbas'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'agricultural', 'disaster', 'management'], ['big', 'data', 'based', 'security', 'analytics', 'protecting', 'virtualized', 'infrastructure', 'cloud', 'computing'], ['tv', 'audience', 'measurement', 'big', 'data'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'intelligent', 'system', 'cybersecurity'], ['new', 'discrimination', 'diagram', 'basalt', 'based', 'big', 'data', 'research'], ['ensemble', 'based', 'scalable', 'approach', 'intrusion', 'detection', 'using', 'big', 'data', 'framework'], ['data', 'science', 'oceanography', 'small', 'data', 'big', 'data'], ['call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'agricultural', 'disaster', 'management'], ['big', 'data', 'enabler', 'primary', 'education'], ['big', 'multimodal', 'data', 'analysis', 'model', 'performance', 'analysis'], ['efficient', 'ensemble', 'based', 'classification', 'framework', 'big', 'medical', 'data'], ['unsupervised', 'tensor', 'mining', 'big', 'data', 'practitioner'], ['big', 'data', 'analytics', 'data', 'management', 'perspective', 'public', 'administration'], ['comparison', 'scalability', 'batch', 'big', 'data', 'processing', 'apache', 'spark', 'apache', 'flink'], ['big', 'data', 'little', 'data', 'care', 'coordination', 'medicare', 'beneficiary', 'medigap', 'coverage'], ['rst', 'de', 'rough', 'set', 'based', 'new', 'differential', 'evolution', 'algorithm', 'scalable', 'big', 'data', 'feature', 'selection', 'distributed', 'computing', 'platform'], ['national', 'survey', 'population', 'health', 'big', 'data', 'analytics', 'mobile', 'health', 'monitor'], ['big', 'data', 'healthcare', 'opportunity', 'challenge'], ['big', 'data', 'lost', 'cloud'], ['big', 'data', 'application', 'guangzhou', 'restaurant', 'analysis'], ['call', 'special', 'issue', 'paper', 'programming', 'model', 'algorithm', 'big', 'data'], ['call', 'special', 'issue', 'paper', 'multimedia', 'big', 'data', 'analytics', 'engineering', 'education'], ['online', 'analytical', 'processing', 'business', 'intelligence', 'big', 'data'], ['call', 'special', 'issue', 'paper', 'soft', 'computing', 'model', 'big', 'data', 'internet', 'thing'], ['remotely', 'sensed', 'big', 'data', 'ocean', 'polar', 'region'], ['message', 'editor', 'chief', 'big', 'data'], ['inte ...

# %%
words2 = list(reduce(lambda x, y: x+y, words))
print(words2) #출력하여 내용 확인
# Out:
# ['call', 'special', 'issue', 'paper', 'soft', 'computing', 'model', 'big', 'data', 'internet', 'thing', 'big', 'data', 'efficient', 'market', 'end', 'daily', 'fantasy', 'sport', 'know', 'big', 'data', 'predictive', 'analytics', 'health', 'care', 'call', 'special', 'issue', 'paper', 'internet', 'medical', 'thing', 'big', 'data', 'pervasive', 'medical', 'care', 'big', 'data', 'literature', 'search', 'big', 'data', 'ensemble', 'clinical', 'prediction', 'healthcare', 'data', 'using', 'deep', 'learning', 'model', 'call', 'special', 'issue', 'paper', 'cloud', 'computing', 'big', 'data', 'cognitive', 'iot', 'call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'industrial', 'intelligence', 'u', 'army', 'person', 'event', 'data', 'environment', 'military', 'civilian', 'big', 'data', 'enterprise', 'exploiting', 'reused', 'based', 'sharing', 'work', 'opportunity', 'big', 'data', 'multiquery', 'optimization', 'flink', 'big', 'data', 'machine', 'analyze', 'stock', 'market', 'sentiment', 'overcoming', 'resistance', 'big', 'data', 'operational', 'change', 'interactive', 'data', 'visualization', 'call', 'special', 'issue', 'paper', 'multimedia', 'big', 'data', 'analytics', 'engineering', 'education', 'big', 'data', 'lost', 'cloud', 'call', 'special', 'issue', 'paper', 'cloud', 'computing', 'big', 'data', 'cognitive', 'iot', 'big', 'data', 'social', 'good', 'big', 'data', 'rise', 'machine', 'financial', 'market', 'big', 'data', 'support', 'sustainable', 'development', 'goal', 'continued', 'celebration', 'establishment', 'international', 'research', 'center', 'big', 'data', 'sustainable', 'development', 'goal', 'cbas', 'call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'agricultural', 'disaster', 'management', 'big', 'data', 'based', 'security', 'analytics', 'protecting', 'virtualized', 'infrastructure', 'cloud', 'computing', 'tv', 'audience', 'measurement', 'big', 'data', 'call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'intelligent', 'system', 'cybersecurity', 'new', 'discrimination', 'diagram', 'basalt', 'based', 'big', 'data', 'research', 'ensemble', 'based', 'scalable', 'approach', 'intrusion', 'detection', 'using', 'big', 'data', 'framework', 'data', 'science', 'oceanography', 'small', 'data', 'big', 'data', 'call', 'special', 'issue', 'paper', 'big', 'data', 'analytics', 'agricultural', 'disaster', 'management', 'big', 'data', 'enabler', 'primary', 'education', 'big', 'multimodal', 'data', 'analysis', 'model', 'performance', 'analysis', 'efficient', 'ensemble', 'based', 'classification', 'framework', 'big', 'medical', 'data', 'unsupervised', 'tensor', 'mining', 'big', 'data', 'practitioner', 'big', 'data', 'analytics', 'data', 'management', 'perspective', 'public', 'administration', 'comparison', 'scalability', 'batch', 'big', 'data', 'processing', 'apache', 'spark', 'apache', 'flink', 'big', 'data', 'little', 'data', 'care', 'coordination', 'medicare', 'beneficiary', 'medigap', 'coverage', 'rst', 'de', 'rough', 'set', 'based', 'new', 'differential', 'evolution', 'algorithm', 'scalable', 'big', 'data', 'feature', 'selection', 'distributed', 'computing', 'platform', 'national', 'survey', 'population', 'health', 'big', 'data', 'analytics', 'mobile', 'health', 'monitor', 'big', 'data', 'healthcare', 'opportunity', 'challenge', 'big', 'data', 'lost', 'cloud', 'big', 'data', 'application', 'guangzhou', 'restaurant', 'analysis', 'call', 'special', 'issue', 'paper', 'programming', 'model', 'algorithm', 'big', 'data', 'call', 'special', 'issue', 'paper', 'multimedia', 'big', 'data', 'analytics', 'engineering', 'education', 'online', 'analytical', 'processing', 'business', 'intelligence', 'big', 'data', 'call', 'special', 'issue', 'paper', 'soft', 'computing', 'model', 'big', 'data', 'internet', 'thing', 'remotely', 'sensed', 'big', 'data', 'ocean', 'polar', 'region', 'message', 'editor', 'chief', 'big', 'data', 'intelligent', 'big', 'data', 'analysis', 'review', 'agile', 'big', 'data', 'analytics', 'web' ...

# %% [markdown]
# # 5. 데이터 탐색 및 분석 모델 구축

# %% [markdown]
# ## 1. 데이터 탐색 - 단어 빈도 구하기

# %%
count = Counter(words2)
count #출력하여 내용 확인
# Out:
# Counter({'call': 34,
#          'special': 37,
#          'issue': 48,
#          'paper': 32,
#          'soft': 2,
#          'computing': 25,
#          'model': 46,
#          'big': 1112,
#          'data': 1239,
#          'internet': 18,
#          'thing': 15,
#          'efficient': 18,
#          'market': 9,
#          'end': 2,
#          'daily': 1,
#          'fantasy': 1,
#          'sport': 4,
#          'know': 1,
#          'predictive': 7,
#          'analytics': 113,
#          'health': 31,
#          'care': 11,
#          'medical': 15,
#          'pervasive': 1,
#          'literature': 5,
#          'search': 7,
#          'ensemble': 4,
#          'clinical': 11,
#          'prediction': 15,
#          'healthcare': 16,
#          'using': 56,
#          'deep': 13,
#          'learning': 48,
#          'cloud': 30,
#          'cognitive': 4,
#          'iot': 9,
#          'industrial': 8,
#          'intelligence': 21,
#          'u': 8,
#          'army': 2,
#          'person': 1,
#          'event': 1,
#          'environment': 13,
#          'military': 1,
#          'civilian': 1,
#          'enterprise': 7,
#          'exploiting': 3,
#          'reused': 1,
#          'based': 102,
#          'sharing': 10,
#          'work': 10,
#          'opportunity': 28,
#          'multiquery': 1,
#          'optimization': 24,
#          'flink': 2,
#          'machine': 26,
#          'analyze': 2,
#          'stock': 4,
#          'sentiment': 5,
#          'overcoming': 1,
#          'resistance': 3,
#          'operational': 3,
#          'change': 3,
#          'interactive': 2,
#          'visualization': 7,
#          'multimedia': 5,
#          'engineering': 13,
#          'education': 9,
#          'lost': 2,
#          'social': 17,
#          'good': 6,
#          'rise': 2,
#          'financial': 10,
#          'support': 12,
#          'sustainable': 17,
#          'development': 20,
#          'goal': 12,
#          'continued': 3,
#          'celebration': 2,
#          'establishment': 3,
#          'international': 6,
#          'research': 34,
#          'center': 7,
#          'cbas': 2,
#          'agricultural': 5,
#          'disaster': 6,
#          'management': 36,
#          'security': 16,
#          'protecting': 1,
#          'virtualized': 1,
#          'infrastructure': 12,
#          'tv': 1,
#          'audience': 1,
#          'measurement': 7,
#          'intelligent': 14,
#          'system': 62,
#          'cybersecurity': 4,
#          'new': 39,
#          'discrimination': 2,
#          'diagram': 1,
#          'basalt': 1,
#          'scalable': 14,
#          'approach': 56,
#          'intrusion': 1,
#          'detection': 12,
#          'framework': 36,
#          'science': 34,
#          'oceanography': 1,
#          'small': 18,
#          'enabler': 1,
#          'primary': 2,
#          'multimodal': 2,
#          'analysis': 97,
#          'performance': 25,
#          'classification': 11,
#          'unsupervised': 1,
#          'tensor': 4,
#          'mining': 26,
#          'practitioner': 2,
#          'perspective': 24,
#          'public': 9,
#          'administration': 2,
#          'comparison': 2,
#          'scalability': 1,
#          'batch': 2,
#          'processing': 26,
#          'apache': 4,
#          'spark': 5,
#          'little': 10,
#          'coordination': 1,
#          'medicare': 1,
#          'beneficiary': 1,
#          'medigap': 1,
#          'coverage': 2,
#          'rst': 1,
#          'de': 2,
#          'rough': 1,
#          'set': 4,
#          'differential': 1,
#          'evolution': 4,
#          'algorithm': 36,
#          'feature': 6,
#          'selection': 9,
#          'distributed': 23,
#          'platform': 34,
#          'national': 5,
#          'survey': 19,
#          'population': 4,
#          'mobile': 7,
#          'monitor': 1,
#          'challenge': 44,
#          'application': 40,
#          'guangzhou': 1,
#          'restaurant': 1,
#          'programming': 3,
#          'online': 13,
#          'analytical': 2,
#          'business': 24,
#          'remotely': 1,
#          'sensed': 1,
#          'ocean': 2,
#          'polar': 1,
#          'region': 3,
#          'message': 4,
#          'editor': 3,
#          'chief': 1,
#          'review': 22,
#          'agile': 1,
#          'web': 8,
#          'architecture': 12,
#          'centric': 2,
#          'current': 9,
#          'potential': 8,
#          'solution': 12,
#          'analyzing': 6,
#          'smart': 24,
#          'metering': 2,
#          'towards': 12,
#          'differentiated': 1,
#          'user': 5,
#          'service': 21,
#          'sublinear': 1,
#          'modelling': 3,
#          'clustering': 11,
#          'spatiotemporal': 1,
#          'interval': 3,
#          'leveraging': 7,
#          'case': 13,
#          'kenyan': 1,
#          'telecom': 2,
#          'border': 1,
#          'crossing': 1,
#          'transportation': 7,
#          'improved': 5,
#          'index': 6,
#          'cnn': 1,
#          'gru': 1,
#          'guest': 13,
#          'editorial': 16,
#          'scholar': 3,
#          'discovery': 13,
#          'collaboration': 6,
#          'landscape': 3,
#          'influence': 2,
#          'finance': 2,
#          'speed': 1,
#          'unveiling': 1,
#          'storage': 9,
#          'distribution': 10,
#          'sub': 1,
#          'datasets': 2,
#          'overview': 4,
#          'recent': 5,
#          'fuzzy': 7,
#          'investigating': 1,
#          'class': 1,
#          'rarity': 1,
#          'understanding': 13,
#          'trend': 10,
#          'technology': 26,
#          'patent': 2,
#          'cited': 1,
#          'scholarly': 5,
#          'petuum': 1,
#          'real': 20,
#          'time': 18,
#          'availability': 1,
#          'assurance': 1,
#          'palopro': 1,
#          'knowledge': 12,
#          'extraction': 3,
#          'news': 4,
#          'hierarchical': 1,
#          'image': 5,
#          'corporate': 3,
#          'governance': 5,
#          'fraud': 3,
#          'annual': 1,
#          'report': 3,
#          'concentric': 1,
#          'value': 10,
#          'monitoring': 12,
#          'camera': 1,
#          'driven': 71,
#          'surveillance': 1,
#          'video': 1,
#          'quality': 8,
#          'consistency': 2,
#          'hdm': 1,
#          'composable': 1,
#          'enhanced': 4,
#          'method': 25,
#          'aid': 1,
#          'behavioral': 3,
#          'trajectory': 2,
#          'pattern': 11,
#          'recognition': 1,
#          'longitudinal': 1,
#          'context': 9,
#          'aware': 7,
#          'optimized': 2,
#          'eeg': 2,
#          'seizure': 1,
#          'bci': 1,
#          'via': 10,
#          'reference': 4,
#          'introducing': 1,
#          'perform': 1,
#          'ieee': 2,
#          'transaction': 2,
#          'vol': 2,
#          'hybridisation': 1,
#          'classifier': 3,
#          'anomaly': 3,
#          'structural': 3,
#          'balance': 2,
#          'theory': 5,
#          'e': 7,
#          'commerce': 3,
#          'recommendation': 7,
#          'rating': 3,
#          'similarity': 2,
#          'overfitting': 1,
#          'multi': 12,
#          'branch': 1,
#          'decoder': 1,
#          'network': 27,
#          'adaptive': 6,
#          'temporal': 5,
#          'reconstruction': 2,
#          'scientific': 10,
#          'simulation': 3,
#          'scale': 13,
#          'secure': 3,
#          'owner': 1,
#          'scheme': 6,
#          'algorithmseer': 1,
#          'extracting': 2,
#          'searching': 1,
#          'handling': 4,
#          'max': 1,
#          'min': 1,
#          'fair': 1,
#          'resource': 6,
#          'allocation': 5,
#          'stream': 4,
#          'shared': 2,
#          'five': 3,
#          'layer': 2,
#          'extended': 3,
#          'spatio': 3,
#          'granger': 1,
#          'causality': 1,
#          'air': 4,
#          'estimation': 6,
#          'heterogeneous': 5,
#          'urban': 6,
#          'taxi': 2,
#          'passenger': 1,
#          'demand': 3,
#          'modeling': 12,
#          'roving': 1,
#          'sensor': 7,
#          'resting': 1,
#          'state': 12,
#          'fmri': 2,
#          'functional': 1,
#          'connectivity': 1,
#          'preprocessing': 1,
#          'pipeline': 3,
#          'topological': 1,
#          'dip': 1,
#          'svm': 2,
#          'preserving': 3,
#          'kernel': 5,
#          'vector': 3,
#          'evolving': 2,
#          'role': 13,
#          'fpga': 1,
#          'toward': 7,
#          'flexible': 3,
#          'metadata': 2,
#          'indexing': 1,
#          'economic': 1,
#          'x': 5,
#          'cell': 4,
#          'phone': 1,
#          'compute': 2,
#          'mobility': 5,
#          'scenario': 3,
#          'future': 18,
#          'city': 8,
#          'semantics': 4,
#          'mongodb': 1,
#          'modular': 1,
#          'ontology': 2,
#          'building': 8,
#          'integration': 5,
#          'heavy': 1,
#          'tailed': 1,
#          'rule': 4,
#          'mapreduce': 8,
#          'granularity': 1,
#          'insight': 9,
#          'incremental': 5,
#          'query': 4,
#          'unlocking': 1,
#          'causal': 1,
#          'relation': 2,
#          'barrier': 2,
#          'manufacturing': 6,
#          'firm': 6,
#          'comprehensive': 3,
#          'embedding': 1,
#          'factory': 1,
#          'sap': 1,
#          'consultant': 1,
#          'updating': 1,
#          'correct': 1,
#          'error': 6,
#          'straggler': 1,
#          'optimal': 2,
#          'rescheduling': 1,
#          'slow': 1,
#          'running': 1,
#          'task': 2,
#          'lfcso': 1,
#          'lvq': 1,
#          'pso': 1,
#          'comparing': 2,
#          'world': 22,
#          'regional': 3,
#          'supply': 6,
#          'chain': 7,
#          'bibliometric': 4,
#          'evaluating': 4,
#          'effect': 2,
#          'global': 9,
#          'responding': 1,
#          'turbulence': 1,
#          'mass': 1,
#          'customization': 1,
#          'capability': 10,
#          'retail': 1,
#          'apriori': 1,
#          'skyline': 1,
#          'computation': 2,
#          'exploring': 7,
#          'path': 1,
#          'implementation': 4,
#          'success': 2,
#          'banking': 1,
#          'integrated': 1,
#          'analysing': 3,
#          'repeat': 1,
#          'blood': 2,
#          'donation': 2,
#          'behavior': 8,
#          'mr': 2,
#          'plot': 1,
#          'tool': 4,
#          'distinguishing': 1,
#          'subdata': 1,
#          'sampling': 4,
#          'watchdog': 1,
#          'name': 1,
#          'matching': 1,
#          'risk': 14,
#          'problem': 12,
#          'device': 8,
#          'supervised': 2,
#          'compression': 5,
#          'design': 11,
#          'methodology': 4,
#          'warehouse': 5,
#          'process': 22,
#          'stakeholder': 3,
#          'perception': 4,
#          'word': 1,
#          'mouth': 1,
#          'csr': 1,
#          'dynamic': 8,
#          'twitter': 3,
#          'holistic': 2,
#          'view': 4,
#          'advancing': 2,
#          'multiple': 4,
#          'decisional': 1,
#          'bayesian': 4,
#          'consensus': 1,
#          'lime': 1,
#          'hyper': 1,
#          'convergent': 2,
#          'innovation': 11,
#          'predicting': 6,
#          'amazon': 1,
#          'product': 6,
#          'pcce': 1,
#          'personality': 1,
#          'communicative': 1,
#          'community': 3,
#          'uncertainty': 6,
#          'measure': 1,
#          'fusion': 5,
#          'conflict': 1,
#          'evidence': 10,
#          'dempster': 1,
#          'shafer': 1,
#          'bit': 1,
#          'oriented': 6,
#          'aggregation': 3,
#          'feasibility': 1,
#          'regression': 2,
#          'novel': 8,
#          'broadcasting': 1,
#          'graph': 5,
#          'transforming': 5,
#          'v': 4,
#          'non': 5,
#          'simple': 2,
#          'pre': 2,
#          'bias': 2,
#          'correction': 4,
#          'sample': 2,
#          'suspicious': 1,
#          'tax': 1,
#          'evasion': 1,
#          'group': 5,
#          'medium': 14,
#          'direction': 2,
#          'step': 1,
#          'nonlinear': 1,
#          'dimension': 4,
#          'reduction': 3,
#          'semi': 1,
#          'automatic': 1,
#          'fact': 1,
#          'ecosystem': 2,
#          'va': 1,
#          'store': 3,
#          'virtual': 2,
#          'approximate': 1,
#          'supporting': 4,
#          'repetitive': 1,
#          'genome': 2,
#          'sequence': 2,
#          'matrix': 3,
#          'decomposition': 2,
#          'k': 9,
#          'nearest': 4,
#          'neighbour': 1,
#          'join': 2,
#          'theoretical': 5,
#          'experimental': 2,
#          'privacy': 12,
#          'implication': 8,
#          'database': 10,
#          'era': 30,
#          'contextual': 2,
#          'federated': 1,
#          'recommender': 1,
#          'sequential': 1,
#          'localization': 2,
#          'telco': 1,
#          'linked': 1,
#          'large': 13,
#          'semantic': 6,
#          'effective': 2,
#          'source': 1,
#          'recursive': 1,
#          'approximation': 5,
#          'fast': 3,
#          'recovery': 2,
#          'sensing': 7,
#          'chunk': 1,
#          'dataset': 1,
#          'sensory': 1,
#          'wireless': 6,
#          'generalized': 3,
#          'canonical': 1,
#          'correlation': 2,
#          'multiview': 1,
#          'neighbor': 3,
#          'skia': 1,
#          'memory': 7,
#          'spatial': 7,
#          'textual': 1,
#          'parallel': 7,
#          'fractional': 1,
#          'hot': 3,
#          'deck': 1,
#          'imputation': 2,
#          'variance': 1,
#          'incomplete': 1,
#          'curing': 1,
#          'vecchia': 1,
#          'laplace': 1,
#          'gaussian': 2,
#          'emulated': 1,
#          'order': 3,
#          'identification': 5,
#          'series': 5,
#          'factorization': 2,
#          'blind': 1,
#          'factor': 4,
#          'distrubted': 1,
#          'dws': 1,
#          'technique': 11,
#          'access': 6,
#          'competitive': 7,
#          'advantage': 5,
#          'china': 19,
#          'car': 5,
#          'hailing': 1,
#          'eu': 1,
#          'law': 4,
#          'face': 2,
#          'shake': 1,
#          'course': 3,
#          'given': 1,
#          'student': 4,
#          'expectation': 1,
#          'industry': 17,
#          'frame': 1,
#          'content': 4,
#          'make': 4,
#          'friendly': 1,
#          'transformation': 8,
#          'semantically': 2,
#          'enriched': 1,
#          'simplified': 2,
#          'commentary': 1,
#          'mo': 2,
#          'study': 20,
#          'orthopaedic': 1,
#          'concern': 3,
#          'generalizability': 1,
#          'exchange': 1,
#          'material': 4,
#          'format': 1,
#          'oracle': 2,
#          'sparc': 2,
#          'accelerates': 1,
#          'processor': 4,
#          'integrate': 1,
#          'hardware': 2,
#          'acceleration': 1,
#          'software': 5,
#          'also': 2,
#          'enable': 2,
#          'working': 2,
#          'field': 6,
#          'augmented': 1,
#          'ethnography': 1,
#          'candidate': 3,
#          'interaction': 1,
#          'election': 1,
#          'ready': 2,
#          'hazy': 1,
#          'making': 15,
#          'easier': 1,
#          'build': 2,
#          'maintain': 1,
#          'racing': 1,
#          'unleash': 1,
#          'full': 1,
#          'latest': 2,
#          'statistical': 9,
#          'energy': 18,
#          'lesson': 4,
#          'assembling': 1,
#          'use': 23,
#          'transfer': 2,
#          'scheduling': 10,
#          'maximizing': 1,
#          'throughput': 2,
#          'three': 2,
#          'dimensional': 3,
#          'aerial': 2,
#          'laser': 1,
#          'scanning': 2,
#          'technologien': 1,
#          'der': 5,
#          'fahrzeugentwicklung': 1,
#          'spectrum': 3,
#          'communication': 6,
#          'g': 1,
#          'screening': 3,
#          'bregman': 1,
#          'divergence': 1,
#          'stack': 1,
#          'seismic': 1,
#          'inversion': 1,
#          'growth': 4,
#          'impact': 14,
#          'satellite': 2,
#          'yearly': 1,
#          'generation': 8,
#          'aiaa': 1,
#          'streaming': 1,
#          'concept': 3,
#          'drift': 1,
#          'safety': 8,
#          'decision': 16,
#          'conceptual': 4,
#          'influencing': 2,
#          'protein': 2,
#          'structure': 2,
#          'metagenomics': 1,
#          'give': 1,
#          'boost': 3,
#          'high': 13,
#          'quantification': 1,
#          'variation': 1,
#          'bioinformatics': 2,
#          'workflow': 3,
#          'comparative': 3,
#          'assessment': 11,
#          'type': 2,
#          'gene': 4,
#          'expression': 2,
#          'carbon': 3,
#          'emission': 1,
#          'walkable': 1,
#          'green': 9,
#          'charge': 1,
#          'consumption': 2,
#          'electric': 6,
#          'vehicle': 7,
#          'exception': 1,
#          'parallelized': 1,
#          'incorporating': 1,
#          'smallholder': 2,
#          'palm': 1,
#          'oil': 4,
#          'production': 6,
#          'revamp': 1,
#          'computational': 8,
#          'toxicology': 1,
#          'government': 6,
#          'sector': 7,
#          'precision': 2,
#          'medicine': 8,
#          'starting': 2,
#          'custom': 1,
#          'made': 3,
#          'iatrology': 1,
#          'key': 4,
#          'efficiency': 6,
#          'mean': 8,
#          'difference': 2,
#          'warum': 1,
#          'sie': 1,
#          'noch': 1,
#          'lange': 1,
#          'darauf': 1,
#          'warten': 1,
#          'sollten': 1,
#          'institutional': 1,
#          'driving': 2,
#          'evaluation': 6,
#          'combination': 2,
#          'circumstance': 1,
#          'ist': 2,
#          'da': 1,
#          'und': 6,
#          'bedeutet': 1,
#          'f': 5,
#          'r': 9,
#          'wissenschaft': 1,
#          'wirtschaft': 1,
#          'gesellschaft': 1,
#          'trading': 1,
#          'herausforderungen': 1,
#          'potenziale': 1,
#          'deutsche': 1,
#          'softwareunternehmen': 1,
#          'progress': 2,
#          'headache': 2,
#          'medicinal': 1,
#          'chemistry': 1,
#          'anti': 3,
#          'cancer': 5,
#          'drug': 8,
#          'qualitative': 3,
#          'digital': 16,
#          'crawling': 2,
#          'rapidminer': 2,
#          'electrical': 1,
#          'capacitance': 1,
#          'tomography': 1,
#          'librarian': 4,
#          'managing': 5,
#          'unmanageable': 1,
#          'revolution': 12,
#          'transform': 7,
#          'live': 5,
#          'think': 7,
#          'viktor': 1,
#          'mayer': 1,
#          'schonberger': 1,
#          'kenneth': 1,
#          'cukier': 1,
#          'adding': 1,
#          'boon': 2,
#          'transport': 2,
#          'geography': 1,
#          'finder': 1,
#          'keeper': 1,
#          'loser': 1,
#          'weeper': 1,
#          'bad': 2,
#          'sensitivity': 2,
#          'policy': 9,
#          'imperfect': 1,
#          'information': 23,
#          'beginning': 2,
#          'incoming': 1,
#          'vehicular': 1,
#          'ad': 2,
#          'hoc': 1,
#          'networking': 2,
#          'political': 7,
#          'sociology': 1,
#          'practice': 11,
#          'alzheimer': 5,
#          'disease': 8,
#          'environmental': 7,
#          'scan': 1,
#          'geoinformatics': 3,
#          'h': 1,
#          'karimi': 2,
#          'crc': 2,
#          'press': 3,
#          'taylor': 1,
#          'francis': 1,
#          'london': 1,
#          'pp': 4,
#          'price': 4,
#          'isbn': 4,
#          'deterioration': 1,
#          'assetmetrics': 1,
#          'stroke': 2,
#          'epidemiology': 4,
#          'united': 5,
#          'lsgdm': 1,
#          'circular': 3,
#          'economy': 4,
#          'personal': 3,
#          'protective': 2,
#          'equipment': 2,
#          'stockpiling': 2,
#          'universal': 2,
#          'control': 12,
#          'prevention': 3,
#          'covid': 6,
#          'expanding': 3,
#          'buck': 2,
#          'backing': 1,
#          'lobbying': 1,
#          'effort': 2,
#          'capitol': 1,
#          'hill': 1,
#          'creating': 1,
#          'right': 1,
#          'shrinking': 1,
#          'pathogen': 1,
#          'philosophy': 3,
#          'element': 1,
#          'question': 8,
#          'open': 6,
#          'powerful': 1,
#          'disparate': 1,
#          'blueprint': 1,
#          'america': 1,
#          'probed': 1,
#          'citizen': 1,
#          'life': 4,
#          'never': 1,
#          'putting': 3,
#          'cart': 1,
#          'horse': 1,
#          'analyse': 3,
#          'first': 3,
#          'katharine': 1,
#          'bagshaw': 1,
#          'fca': 1,
#          'examines': 1,
#          'scope': 1,
#          'audit': 4,
#          'pharmacology': 1,
#          'patentometrics': 1,
#          'abnormal': 2,
#          'association': 4,
#          'paas': 1,
#          'disk': 1,
#          'container': 1,
#          'virtualization': 1,
#          'meaning': 2,
#          'bringing': 1,
#          'chaos': 1,
#          'next': 7,
#          'disclosure': 1,
#          'target': 3,
#          'customer': 6,
#          'methodological': 2,
#          'tourism': 3,
#          'cbc': 1,
#          'diff': 1,
#          'practical': 4,
#          'methylated': 1,
#          'associated': 3,
#          'prognosis': 1,
#          'ovarian': 1,
#          'normal': 1,
#          'accident': 1,
#          'waiting': 1,
#          'happen': 1,
#          'aspect': 1,
#          'animal': 2,
#          'brazilian': 1,
#          'genomics': 3,
#          'academic': 2,
#          'marketization': 1,
#          'crunch': 2,
#          'pharma': 1,
#          'precise': 1,
#          'diagnosis': 5,
#          'space': 5,
#          'range': 1,
#          'alexander': 1,
#          'von': 2,
#          'humboldt': 1,
#          'artificial': 5,
#          'calibration': 1,
#          'hyperspectral': 1,
#          'universe': 1,
#          'astronomy': 1,
#          'tiger': 1,
#          'reaction': 1,
#          'anticorruption': 1,
#          'campaign': 2,
#          'feedback': 1,
#          'utility': 3,
#          'seek': 1,
#          'extract': 1,
#          'asset': 4,
#          'grid': 7,
#          'becoming': 4,
#          'gold': 1,
#          'mine': 3,
#          'improve': 9,
#          'save': 2,
#          'money': 1,
#          'cheerleader': 1,
#          'translational': 1,
#          'perioperative': 1,
#          'imaging': 3,
#          'guiding': 1,
#          'patient': 13,
#          'centered': 1,
#          'manage': 1,
#          'drown': 1,
#          'exponential': 1,
#          'challenging': 2,
#          'ability': 1,
#          'effectively': 1,
#          'exploit': 1,
#          'contains': 1,
#          'dark': 1,
#          'side': 1,
#          'unintended': 1,
#          'consequence': 2,
#          'introduction': 6,
#          'informed': 2,
#          'handprint': 1,
#          'topic': 2,
#          'typical': 1,
#          'treatment': 3,
#          'film': 2,
#          'television': 1,
#          'im': 1,
#          'gesundheitsrecht': 1,
#          'ende': 1,
#          'datensparsamkeit': 1,
#          'whole': 1,
#          'yotta': 1,
#          'byte': 1,
#          'look': 4,
#          'best': 2,
#          'enabled': 9,
#          'digestive': 1,
#          'politics': 5,
#          'brother': 3,
#          'tnani': 1,
#          'schneidern': 1,
#          'ed': 1,
#          'londonroutledge': 1,
#          'exploratory': 1,
#          'seeking': 2,
#          'discussion': 4,
#          'experience': 3,
#          'account': 1,
#          'scientist': 2,
#          'intensive': 3,
#          'remote': 4,
#          'getting': 1,
#          'applying': 4,
#          'critical': 6,
#          'realism': 1,
#          'hype': 2,
#          'hybrid': 4,
#          'repairing': 1,
#          'cleaning': 1,
#          'cso': 1,
#          'gsa': 1,
#          'bet': 1,
#          'agency': 1,
#          'initiative': 3,
#          'offer': 5,
#          'array': 1,
#          'collect': 1,
#          'gathering': 4,
#          'wsn': 1,
#          'convex': 2,
#          'randomized': 3,
#          'christine': 3,
#          'l': 3,
#          'borgman': 3,
#          'scholarship': 7,
#          'networked': 6,
#          'provides': 4,
#          'minimize': 1,
#          'optimize': 3,
#          'unlock': 2,
#          'interdisciplinary': 1,
#          'temporally': 1,
#          'complex': 4,
#          'heterogenous': 1,
#          'bibliographic': 1,
#          ...})

# %%
word_count = dict()

for tag, counts in count.most_common(50):
    if(len(str(tag))>1):
        word_count[tag] = counts
        print("%s : %d" % (tag, counts))
# Out:
# data : 1239
# big : 1112
# analytics : 113
# based : 102
# analysis : 97
# driven : 71
# system : 62
# using : 56
# approach : 56
# issue : 48
# learning : 48
# model : 46
# challenge : 44
# application : 40
# new : 39
# special : 37
# management : 36
# framework : 36
# algorithm : 36
# call : 34
# research : 34
# science : 34
# platform : 34
# paper : 32
# health : 31
# cloud : 30
# era : 30
# opportunity : 28
# network : 27
# machine : 26
# mining : 26
# processing : 26
# technology : 26
# computing : 25
# performance : 25
# method : 25
# earth : 25
# optimization : 24
# perspective : 24
# business : 24
# smart : 24
# distributed : 23
# use : 23
# information : 23
# review : 22
# world : 22
# process : 22
# intelligence : 21
# service : 21
# development : 20

# %% [markdown]
# ## 2. 데이터 탐색 - 히스토그램 그리기

# %%
sorted_Keys = sorted(word_count, key = word_count.get, reverse = True)
sorted_Values = sorted(word_count.values(), reverse = True)
plt.bar(range(len(word_count)), sorted_Values, align = 'center')
plt.xticks( range(len(word_count)), list(sorted_Keys), rotation = 85)
plt.show()

# %% [markdown]
# ###  - 'big', 'data'를 제외하고, 단어빈도 히스토그램 그리기

# %%
word_count2 = word_count
del word_count2['big']
del word_count2['data']

# %%
sorted_Keys = sorted(word_count2, key = word_count.get, reverse = True)
sorted_Values = sorted(word_count2.values(), reverse = True)
plt.bar(range(len(word_count2)), sorted_Values, align = 'center')
plt.xticks( range(len(word_count2)), list(sorted_Keys), rotation = 85)
plt.show()

# %% [markdown]
# # 6. 결과 시각화

# %%
all_files_data_concat['doc_count'] = 0
summary_year = all_files_data_concat.groupby('출판일', as_index = False)['doc_count'].count()
summary_year #출력하여 내용 확인
# Out:
#      출판일  doc_count
# 0   2003          1
# 1   2004          1
# 2   2011          5
# 3   2012         19
# 4   2013         50
# 5   2014        124
# 6   2015         92
# 7   2016        112
# 8   2017        129
# 9   2018        118
# 10  2019         90
# 11  2020        105
# 12  2021         90
# 13  2022         60
# 14  2023          4

# %%
plt.figure(figsize = (12, 5))
plt.xlabel("year")
plt.ylabel("doc-count")
plt.grid(True)
plt.plot(range(len(summary_year)), summary_year['doc_count'])
plt.xticks( range(len(summary_year)), [text for text in summary_year['출판일']])
plt.show()

# %%
stopwords = set(STOPWORDS)
wc = WordCloud(background_color = 'ivory', stopwords = stopwords,width = 800, height = 600)
cloud = wc.generate_from_frequencies(word_count)
plt.figure(figsize = (8,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
cloud.to_file("riss_bigdata_wordCloud.jpg")
